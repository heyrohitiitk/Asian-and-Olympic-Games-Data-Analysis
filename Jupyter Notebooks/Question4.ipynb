# %% [markdown]
# # Q4. Medals won as host country v/s non host counry:

# %%
#Importing neccesary packages:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Importing the required dataset:
df_o1=pd.read_csv('Players_Medal_list_Olympics.csv')
df_o2=pd.read_csv('Medal_List_Olympics.csv')
df_a1=pd.read_csv('Players_Medal_List_Asian.csv')
df_a2=pd.read_csv('Medal_List_Asian.csv')

# %%
#Olympic Athlete Dataset:
df_o1
# Out:
#                       Name Gender     Country  Year Host_City          Sport  \
# 0              Takashi Ono      M       Japan  1952  Helsinki     Gymnastics
# 1        Dharam Singh Gill      M       India  1952  Helsinki         Hockey
# 2     Randhir Singh Gentle      M       India  1952  Helsinki         Hockey
# 3      Chinadorai Deshmutu      M       India  1952  Helsinki         Hockey
# 4          Shiro Hashizume      M       Japan  1952  Helsinki       Swimming
# ...                    ...    ...         ...   ...       ...            ...
# 3344      Ulugbek Rashitov      M  Uzbekistan  2020     Tokyo      Taekwondo
# 3345         Akbar Djuraev      M  Uzbekistan  2020     Tokyo  Weightlifting
# 3346      Bakhodir Jalolov      M  Uzbekistan  2020     Tokyo         Boxing
# 3347        Davlat Bobonov      M  Uzbekistan  2020     Tokyo           Judo
# 3348  Bekzod Abdurakhmonov      M  Uzbekistan  2020     Tokyo      Wrestling
#
# ...

# %%
#Olympic Medal Dataset:
df_o2
# Out:
#      Year Host_City       Sport      Country  Gold  Silver  Bronze  Total
# 0    1952  Helsinki      Boxing  South Korea     0       0       1      1
# 1    1952  Helsinki  Gymnastics        Japan     0       0       1      1
# 2    1952  Helsinki  Gymnastics        Japan     0       2       0      2
# 3    1952  Helsinki      Hockey        India     1       0       0      1
# 4    1952  Helsinki    Swimming        Japan     0       1       0      1
# ..    ...       ...         ...          ...   ...     ...     ...    ...
# 833  2020     Tokyo   Wrestling        Japan     5       1       1      7
# 834  2020     Tokyo   Wrestling   Kazakhstan     0       0       1      1
# 835  2020     Tokyo   Wrestling   Kyrgyzstan     0       2       1      3
# 836  2020     Tokyo   Wrestling     Mongolia     0       0       1      1
# 837  2020     Tokyo   Wrestling   Uzbekistan     0       0       1      1
#
# [838 rows x 8 columns]

# %%
#Asian Games athlete dataset:
df_a1
# Out:
#             Player_Name   Gender      Country  Year      Sport  \
# 0          Soichi Tamoi        M        Japan  1951  Athletics
# 1      Ryosuke Takasugi        M        Japan  1951  Athletics
# 2       Gurbachan Singh        M        India  1951  Athletics
# 3        Mahabir Prasad        M        India  1951  Athletics
# 4            Takeo Sato        M        Japan  1951  Athletics
# ...                 ...      ...          ...   ...        ...
# 31015    Tomohiro Araya  Unknown        Japan  2018      Wushu
# 31016  Nyein Chan Ko Ko  Unknown      Myanmar  2018      Wushu
# 31017    Lindswell Kwok        F    Indonesia  2018      Wushu
# 31018       Juanita Mok        F    Hong Kong  2018      Wushu
# 31019       Agatha Wong        F  Philippines  2018      Wushu
#
#                        Event Sport_Type  Gold  Silver  Bronze
# 0                   10,000 m     Single     1       0       0
# 1                   10,000 m     Single     0       1       0
# ...

# %%
#Asian Games medal dataset:
df_a2
# Out:
#       Year      Sport  Rank      Country  Gold  Silver  Bronze  Total
# 0     1951  Athletics     1        Japan    20      17      11     48
# 1     1951  Athletics     2        India    10      12      12     34
# 2     1951  Athletics     3    Singapore     1       2       2      5
# 3     1951  Athletics     4         Iran     1       1       0      2
# 4     1951  Athletics     5  Philippines     1       0       3      4
# ...    ...        ...   ...          ...   ...     ...     ...    ...
# 3403  2018      Wushu     5      Vietnam     0       2       3      5
# 3404  2018      Wushu     6  South Korea     0       1       2      3
# 3405  2018      Wushu     7    Hong Kong     0       1       1      2
# 3406  2018      Wushu     8        Japan     0       1       0      1
# 3407  2018      Wushu     8   Uzbekistan     0       1       0      1
#
# [3408 rows x 8 columns]

# %%
#Converting year column to int type in df_a2, bec. all other dataframes have it in int type:
df_a2['Year']=df_a2['Year'].astype(int)

# %%
#Asian Games medal dataset:
df_a2
# Out:
#       Year      Sport  Rank      Country  Gold  Silver  Bronze  Total
# 0     1951  Athletics     1        Japan    20      17      11     48
# 1     1951  Athletics     2        India    10      12      12     34
# 2     1951  Athletics     3    Singapore     1       2       2      5
# 3     1951  Athletics     4         Iran     1       1       0      2
# 4     1951  Athletics     5  Philippines     1       0       3      4
# ...    ...        ...   ...          ...   ...     ...     ...    ...
# 3403  2018      Wushu     5      Vietnam     0       2       3      5
# 3404  2018      Wushu     6  South Korea     0       1       2      3
# 3405  2018      Wushu     7    Hong Kong     0       1       1      2
# 3406  2018      Wushu     8        Japan     0       1       0      1
# 3407  2018      Wushu     8   Uzbekistan     0       1       0      1
#
# [3408 rows x 8 columns]

# %% [markdown]
# **Creating a dictionary of host countries for Olympic games and Asian games both**

# %%
#We'll use it to generate host country by inputting year value later:
#Since there is no clash in years of Olympic games and Asian games, we can include all in a single dictionary.

dict={"1951":"India","1952":"Finland","1954":"Philippines","1956":"Australia","1958":"Japan","1960":"Italy","1962":"Indonesia",
      "1964":"Japan","1966":"Thailand","1968":"Mexico", "1970":"Thailand","1972":"Germany","1974":"Iran","1976":"Canada",
      "1978":"Thailand","1980":"Russia","1982":"India","1984":"USA","1986":"South Korea","1988":"South Korea","1990":"China",
      "1992":"Spain","1994":"Japan","1996":"USA","1998":"Thailand","2000":"Australia","2002":"South Korea","2004":"Greece",
      "2006":"Qatar","2008":"China", "2010":"China","2012":"UK","2014":"South Korea","2016":"Brazil","2018":"Indonesia",
      "2020":"Japan"}

# %%
#Added new column named 'Host_Country' to dataframe and initialized it's values to 'Year' column values.
df_o1['Host_Country']=df_o1['Year'].astype(str) #Made to string datatype bec. final values will be string type for this col.
#Iterating through Olympic Athlete dataset:
for i in range(len(df_o1)):
    df_o1['Host_Country'].loc[i]=dict[df_o1['Host_Country'].loc[i]] #Used dict key-value pair to generate o/p for this new col.
# Out:
# C:\Users\Deepak Raj\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
#Repeating same process for Olympic medal dataset:
df_o2['Host_Country']=df_o2['Year'].astype(str)
for i in range(len(df_o2)):
    df_o2['Host_Country'].loc[i]=dict[df_o2['Host_Country'].loc[i]]

# %%
"""
#Repeating same process for Asian Games athlete dataset:
df_a1['Host_Country']=df_a1['Year'].astype(str)
for i in range(len(df_a1)):
    df_a1['Host_Country'].loc[i]=dict[df_a1['Host_Country'].loc[i]]
"""
# Out:
# "\n#Repeating same process for Asian Games athlete dataset:\ndf_a1['Host_Country']=df_a1['Year'].astype(str)\nfor i in range(len(df_a1)):\n    df_a1['Host_Country'].loc[i]=dict[df_a1['Host_Country'].loc[i]]\n"

# %%
#Repeating same process for Asian Games medal dataset:
df_a2['Host_Country']=df_a2['Year'].astype(str)
for i in range(len(df_a2)):
    df_a2['Host_Country'].loc[i]=dict[df_a2['Host_Country'].loc[i]]

# %% [markdown]
# **We'll be needing only medal dataset of both Asian games and Olympic games for this question.**

# %%
#Olympic games medal dataset:
df_o2
# Out:
#      Year Host_City       Sport      Country  Gold  Silver  Bronze  Total  \
# 0    1952  Helsinki      Boxing  South Korea     0       0       1      1
# 1    1952  Helsinki  Gymnastics        Japan     0       0       1      1
# 2    1952  Helsinki  Gymnastics        Japan     0       2       0      2
# 3    1952  Helsinki      Hockey        India     1       0       0      1
# 4    1952  Helsinki    Swimming        Japan     0       1       0      1
# ..    ...       ...         ...          ...   ...     ...     ...    ...
# 833  2020     Tokyo   Wrestling        Japan     5       1       1      7
# 834  2020     Tokyo   Wrestling   Kazakhstan     0       0       1      1
# 835  2020     Tokyo   Wrestling   Kyrgyzstan     0       2       1      3
# 836  2020     Tokyo   Wrestling     Mongolia     0       0       1      1
# 837  2020     Tokyo   Wrestling   Uzbekistan     0       0       1      1
#
#     Host_Country
# 0        Finland
# 1        Finland
# 2        Finland
# ...

# %%
#Asian games medal dataset:
df_a2
# Out:
#       Year      Sport  Rank      Country  Gold  Silver  Bronze  Total  \
# 0     1951  Athletics     1        Japan    20      17      11     48
# 1     1951  Athletics     2        India    10      12      12     34
# 2     1951  Athletics     3    Singapore     1       2       2      5
# 3     1951  Athletics     4         Iran     1       1       0      2
# 4     1951  Athletics     5  Philippines     1       0       3      4
# ...    ...        ...   ...          ...   ...     ...     ...    ...
# 3403  2018      Wushu     5      Vietnam     0       2       3      5
# 3404  2018      Wushu     6  South Korea     0       1       2      3
# 3405  2018      Wushu     7    Hong Kong     0       1       1      2
# 3406  2018      Wushu     8        Japan     0       1       0      1
# 3407  2018      Wushu     8   Uzbekistan     0       1       0      1
#
#      Host_Country
# 0           India
# 1           India
# 2           India
# 3           India
# 4           India
# ...

# %% [markdown]
# **For our first major comparison we'll need 2 main tables: df_o2 and df_a2.**

# %% [markdown]
# ## Olympic data Analysis:

# %%
#Olympic games medal dataset:
df_o2
# Out:
#      Year Host_City       Sport      Country  Gold  Silver  Bronze  Total  \
# 0    1952  Helsinki      Boxing  South Korea     0       0       1      1
# 1    1952  Helsinki  Gymnastics        Japan     0       0       1      1
# 2    1952  Helsinki  Gymnastics        Japan     0       2       0      2
# 3    1952  Helsinki      Hockey        India     1       0       0      1
# 4    1952  Helsinki    Swimming        Japan     0       1       0      1
# ..    ...       ...         ...          ...   ...     ...     ...    ...
# 833  2020     Tokyo   Wrestling        Japan     5       1       1      7
# 834  2020     Tokyo   Wrestling   Kazakhstan     0       0       1      1
# 835  2020     Tokyo   Wrestling   Kyrgyzstan     0       2       1      3
# 836  2020     Tokyo   Wrestling     Mongolia     0       0       1      1
# 837  2020     Tokyo   Wrestling   Uzbekistan     0       0       1      1
#
#     Host_Country
# 0        Finland
# 1        Finland
# 2        Finland
# ...

# %%
#Only 3 asian countries have hosted olympic games till now. So, we can analyse for those countries 
df_o2[df_o2['Country']==df_o2['Host_Country']]['Country'].value_counts()
# Out:
# Japan          34
# China          32
# South Korea    12
# Name: Country, dtype: int64

# %%
#Splitting data into 2 dataframes:
host=df_o2[df_o2['Country']==df_o2['Host_Country']].reset_index(drop=True) #Contains countries performance when they are host
non_host=df_o2[df_o2['Country']!=df_o2['Host_Country']].reset_index(drop=True) #Contains countries performance when they are not host

# %%
host
# Out:
#     Year Host_City          Sport Country  Gold  Silver  Bronze  Total  \
# 0   1964     Tokyo      Athletics   Japan     0       0       1      1
# 1   1964     Tokyo         Boxing   Japan     1       0       0      1
# 2   1964     Tokyo     Gymnastics   Japan     1       0       1      2
# 3   1964     Tokyo     Gymnastics   Japan     4       4       0      8
# 4   1964     Tokyo           Judo   Japan     3       1       0      4
# ..   ...       ...            ...     ...   ...     ...     ...    ...
# 73  2020     Tokyo       Swimming   Japan     2       1       0      3
# 74  2020     Tokyo   Table tennis   Japan     0       0       1      1
# 75  2020     Tokyo   Table tennis   Japan     1       1       1      3
# 76  2020     Tokyo  Weightlifting   Japan     0       0       1      1
# 77  2020     Tokyo      Wrestling   Japan     5       1       1      7
#
#    Host_Country
# 0         Japan
# 1         Japan
# 2         Japan
# 3         Japan
# 4         Japan
# ...

# %%
non_host
# Out:
#      Year Host_City       Sport      Country  Gold  Silver  Bronze  Total  \
# 0    1952  Helsinki      Boxing  South Korea     0       0       1      1
# 1    1952  Helsinki  Gymnastics        Japan     0       0       1      1
# 2    1952  Helsinki  Gymnastics        Japan     0       2       0      2
# 3    1952  Helsinki      Hockey        India     1       0       0      1
# 4    1952  Helsinki    Swimming        Japan     0       1       0      1
# ..    ...       ...         ...          ...   ...     ...     ...    ...
# 755  2020     Tokyo   Wrestling         Iran     1       1       2      4
# 756  2020     Tokyo   Wrestling   Kazakhstan     0       0       1      1
# 757  2020     Tokyo   Wrestling   Kyrgyzstan     0       2       1      3
# 758  2020     Tokyo   Wrestling     Mongolia     0       0       1      1
# 759  2020     Tokyo   Wrestling   Uzbekistan     0       0       1      1
#
#     Host_Country
# 0        Finland
# 1        Finland
# 2        Finland
# ...

# %%
#Overall analysis for all years combined:
host=host.groupby(['Year','Country'])['Gold','Silver','Bronze','Total'].agg(sum).reset_index()
# Out:
# C:\Users\DEEPAK~1\AppData\Local\Temp/ipykernel_5984/2014795558.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   host=host.groupby(['Year','Country'])['Gold','Silver','Bronze','Total'].agg(sum).reset_index()

# %%
host
# Out:
#    Year      Country  Gold  Silver  Bronze  Total
# 0  1964        Japan    16       5       8     29
# 1  1988  South Korea    12      10      11     33
# 2  2008        China    51      21      26     98
# 3  2020        Japan    27      14      17     58

# %%
host=host.groupby(['Country'])['Gold','Silver','Bronze','Total'].mean().reset_index()
#If a country has hosted for 2 years. Eg. Japan. Then, we'll aggreate it's medal tally by calculating their mean.
#Means if a country wins 6 golds in 2 years as host, then upon aggregating, that country wins 3 gold medals/year.
# Out:
# C:\Users\DEEPAK~1\AppData\Local\Temp/ipykernel_5984/3774983374.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   host=host.groupby(['Country'])['Gold','Silver','Bronze','Total'].mean().reset_index()

# %%
host=host.rename(columns={'Gold':'Gold/Yr','Silver':'Silver/Yr','Bronze':'Bronze/Yr','Total':'Total/Yr'})

# %%
host
# Out:
#        Country  Gold/Yr  Silver/Yr  Bronze/Yr  Total/Yr
# 0        China     51.0       21.0       26.0      98.0
# 1        Japan     21.5        9.5       12.5      43.5
# 2  South Korea     12.0       10.0       11.0      33.0

# %%
#Repeating same for non host countries:
non_host.groupby(['Year','Country'])['Gold','Silver','Bronze','Total'].agg(sum).reset_index()
# Out:
# C:\Users\DEEPAK~1\AppData\Local\Temp/ipykernel_5984/172437966.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   non_host.groupby(['Year','Country'])['Gold','Silver','Bronze','Total'].agg(sum).reset_index()
#      Year       Country  Gold  Silver  Bronze  Total
# 0    1952         India     1       0       1      2
# 1    1952          Iran     0       3       4      7
# 2    1952         Japan     1       6       1      8
# 3    1952   South Korea     0       0       2      2
# 4    1956         India     1       0       0      1
# ..    ...           ...   ...     ...     ...    ...
# 196  2020   South Korea     6       4      10     20
# 197  2020         Syria     0       0       1      1
# 198  2020      Thailand     1       0       1      2
# 199  2020  Turkmenistan     0       1       0      1
# 200  2020    Uzbekistan     3       0       2      5
#
# [201 rows x 6 columns]

# %%
#Overall analysis:
non_host=non_host.groupby(['Year','Country'])['Gold','Silver','Bronze','Total'].agg(sum).reset_index()
# Out:
# C:\Users\DEEPAK~1\AppData\Local\Temp/ipykernel_5984/1609705489.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   non_host=non_host.groupby(['Year','Country'])['Gold','Silver','Bronze','Total'].agg(sum).reset_index()

# %%
non_host
# Out:
#      Year       Country  Gold  Silver  Bronze  Total
# 0    1952         India     1       0       1      2
# 1    1952          Iran     0       3       4      7
# 2    1952         Japan     1       6       1      8
# 3    1952   South Korea     0       0       2      2
# 4    1956         India     1       0       0      1
# ..    ...           ...   ...     ...     ...    ...
# 196  2020   South Korea     6       4      10     20
# 197  2020         Syria     0       0       1      1
# 198  2020      Thailand     1       0       1      2
# 199  2020  Turkmenistan     0       1       0      1
# 200  2020    Uzbekistan     3       0       2      5
#
# [201 rows x 6 columns]

# %%
non_host=non_host.groupby(['Country'])['Gold','Silver','Bronze','Total'].mean().reset_index()
# Out:
# C:\Users\DEEPAK~1\AppData\Local\Temp/ipykernel_5984/833876694.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   non_host=non_host.groupby(['Country'])['Gold','Silver','Bronze','Total'].mean().reset_index()

# %%
non_host
# Out:
#                  Country       Gold     Silver     Bronze      Total
# 0            Afghanistan   0.000000   0.000000   1.000000   1.000000
# 1                Bahrain   0.333333   0.666667   0.333333   1.333333
# 2                  China  23.222222  18.555556  15.666667  57.444444
# 3         Chinese Taipei   0.454545   1.000000   1.818182   3.272727
# 4              Hong Kong   0.500000   0.750000   1.000000   2.250000
# 5                  India   0.428571   0.500000   1.142857   2.071429
# 6              Indonesia   0.777778   1.444444   1.555556   3.777778
# 7                   Iran   1.312500   1.437500   1.875000   4.625000
# 8                   Iraq   0.000000   0.000000   1.000000   1.000000
# 9                  Japan   7.400000   7.600000   9.133333  24.133333
# 10                Jordan   0.500000   0.500000   0.500000   1.500000
# 11            Kazakhstan   2.714286   3.142857   5.285714  11.142857
# 12                Kuwait   0.000000   0.000000   1.000000   1.000000
# ...

# %%
non_host=non_host.rename(columns={'Gold':'Gold/Yr','Silver':'Silver/Yr','Bronze':'Bronze/Yr','Total':'Total/Yr'})

# %%
non_host=non_host.sort_values(["Gold/Yr","Silver/Yr","Bronze/Yr"],ascending=False).reset_index(drop=True)

# %%
non_host
# Out:
#                  Country    Gold/Yr  Silver/Yr  Bronze/Yr   Total/Yr
# 0                  China  23.222222  18.555556  15.666667  57.444444
# 1                  Japan   7.400000   7.600000   9.133333  24.133333
# 2            South Korea   5.466667   5.200000   5.600000  16.266667
# 3             Kazakhstan   2.714286   3.142857   5.285714  11.142857
# 4             Uzbekistan   1.714286   1.000000   2.714286   5.428571
# 5            North Korea   1.600000   1.500000   2.300000   5.400000
# 6                   Iran   1.312500   1.437500   1.875000   4.625000
# 7               Thailand   0.909091   0.727273   1.272727   2.909091
# 8              Indonesia   0.777778   1.444444   1.555556   3.777778
# 9              Hong Kong   0.500000   0.750000   1.000000   2.250000
# 10                Jordan   0.500000   0.500000   0.500000   1.500000
# 11  United Arab Emirates   0.500000   0.000000   0.500000   1.000000
# 12        Chinese Taipei   0.454545   1.000000   1.818182   3.272727
# ...

# %%
#Filtering data for only those Asian countries that have hosted Olympic games(China, Japan and South Korea):
non_host=non_host[:3]

# %%
non_host
# Out:
#        Country    Gold/Yr  Silver/Yr  Bronze/Yr   Total/Yr
# 0        China  23.222222  18.555556  15.666667  57.444444
# 1        Japan   7.400000   7.600000   9.133333  24.133333
# 2  South Korea   5.466667   5.200000   5.600000  16.266667

# %%
host
# Out:
#        Country  Gold/Yr  Silver/Yr  Bronze/Yr  Total/Yr
# 0        China     51.0       21.0       26.0      98.0
# 1        Japan     21.5        9.5       12.5      43.5
# 2  South Korea     12.0       10.0       11.0      33.0

# %% [markdown]
# **Now, we'll plot graphs on the basis of the data obtained by us:**

# %%
#Total Medals won on an average as hosts and as non hosts comparison graphically:
plt.title("Total medals won as host country and as non host country per year:")
plt.bar(host['Country'],host['Total/Yr'],width=0.1,label='host')
plt.bar(non_host['Country'],non_host['Total/Yr'],width=0.1,label='non-host')
plt.legend()
plt.show()

# %%
#Gold Medals won on an average as hosts and as non hosts comparison graphically:
plt.title("Gold medals won as host country and as non host country per year:")
plt.bar(host['Country'],host['Gold/Yr'],width=0.1,label='host')
plt.bar(non_host['Country'],non_host['Gold/Yr'],width=0.1,label='non-host')
plt.legend()
plt.show()

# %%
#Silver Medals won on an average as hosts and as non hosts comparison graphically:
plt.title("Silver medals won as host country and as non host country per year:")
plt.bar(host['Country'],host['Silver/Yr'],width=0.1,label='host')
plt.bar(non_host['Country'],non_host['Silver/Yr'],width=0.1,label='non-host')
plt.legend()
plt.show()

# %%
#Bronze Medals won on an average as hosts and as non hosts comparison graphically:
plt.title("Bronze medals won as host country and as non host country per year:")
plt.bar(host['Country'],host['Bronze/Yr'],width=0.1,label='host')
plt.bar(non_host['Country'],non_host['Bronze/Yr'],width=0.1,label='non-host')
plt.legend()
plt.show()

# %%
#Medals won on an average as hosts and as non hosts comparison graphically:
plt.title("Medals won as host country and as non host country per year:")
X_axis = np.arange(len(host['Country']))
plt.bar(X_axis - 0.2,host['Total/Yr'],width=0.1,label='host-Total',color='yellow')
plt.bar(X_axis - 0.1,host['Gold/Yr'],width=0.1,label='host-Gold')
plt.bar(X_axis + 0.0,host['Silver/Yr'],width=0.1,label='host-Silver')
plt.bar(X_axis + 0.1,host['Bronze/Yr'],width=0.1,label='host-Bronze')
plt.xticks(X_axis, host['Country'])

plt.bar(X_axis - 0.2,non_host['Total/Yr'],width=0.1,label='non-host-Total')
plt.bar(X_axis - 0.1,non_host['Gold/Yr'],width=0.1,label='non-host-Gold')
plt.bar(X_axis + 0.0,non_host['Silver/Yr'],width=0.1,label='non-host-Silver')
plt.bar(X_axis + 0.1,non_host['Bronze/Yr'],width=0.1,label='non-host-Bronze')
plt.xticks(X_axis, non_host['Country'])

plt.legend()
plt.show()

# %% [markdown]
# **For Olymmpic Games, From the above graph, we can infer that the number of total medals and gold medals are highly affected by playing as host nation. Silver and Bronze are little affected but, they are still more than medals won as non host country.**

# %% [markdown]
# **Other asian countries have never been host in Olympic games from 1950 onwards. So their data is filtered out in this analysis by default.**

# %%
host.to_csv("Q4-a.csv",index=False)

# %%
non_host.to_csv("Q4-b.csv",index=False)

# %% [markdown]
# ## Analysis on Asian Games dataset:

# %%
#Asian games medal dataset:
df_a2
# Out:
#       Year      Sport  Rank      Country  Gold  Silver  Bronze  Total  \
# 0     1951  Athletics     1        Japan    20      17      11     48
# 1     1951  Athletics     2        India    10      12      12     34
# 2     1951  Athletics     3    Singapore     1       2       2      5
# 3     1951  Athletics     4         Iran     1       1       0      2
# 4     1951  Athletics     5  Philippines     1       0       3      4
# ...    ...        ...   ...          ...   ...     ...     ...    ...
# 3403  2018      Wushu     5      Vietnam     0       2       3      5
# 3404  2018      Wushu     6  South Korea     0       1       2      3
# 3405  2018      Wushu     7    Hong Kong     0       1       1      2
# 3406  2018      Wushu     8        Japan     0       1       0      1
# 3407  2018      Wushu     8   Uzbekistan     0       1       0      1
#
#      Host_Country
# 0           India
# 1           India
# 2           India
# 3           India
# 4           India
# ...

# %%
#Only 9 asian countries have hosted asian games till now. So, we can analyse for those countries 
df_a2[df_a2['Country']==df_a2['Host_Country']]['Country'].value_counts()
# Out:
# South Korea    102
# China           67
# Thailand        46
# Japan           45
# Indonesia       37
# India           20
# Qatar           15
# Iran             9
# Philippines      7
# Name: Country, dtype: int64

# %%
#Repeating previous steps. Dividing into 2 dataframes host and non_host:
host=df_a2[df_a2['Country']==df_a2['Host_Country']].reset_index(drop=True)
non_host=df_a2[df_a2['Country']!=df_a2['Host_Country']].reset_index(drop=True)

# %%
host
# Out:
#      Year           Sport  Rank    Country  Gold  Silver  Bronze  Total  \
# 0    1951       Athletics     2      India    10      12      12     34
# 1    1951         Cycling     2      India     0       1       2      3
# 2    1951          Diving     1      India     2       1       1      4
# 3    1951        Football     1      India     1       0       0      1
# 4    1951        Swimming     3      India     1       1       4      6
# ..    ...             ...   ...        ...   ...     ...     ...    ...
# 343  2018  Sport climbing     1  Indonesia     3       2       1      6
# 344  2018       Taekwondo     8  Indonesia     1       0       0      1
# 345  2018          Tennis     3  Indonesia     1       0       0      1
# 346  2018   Weightlifting     4  Indonesia     1       1       1      3
# 347  2018           Wushu     3  Indonesia     1       1       3      5
#
#     Host_Country
# 0          India
# 1          India
# 2          India
# 3          India
# ...

# %%
non_host
# Out:
#       Year      Sport  Rank      Country  Gold  Silver  Bronze  Total  \
# 0     1951  Athletics     1        Japan    20      17      11     48
# 1     1951  Athletics     3    Singapore     1       2       2      5
# 2     1951  Athletics     4         Iran     1       1       0      2
# 3     1951  Athletics     5  Philippines     1       0       3      4
# 4     1951  Athletics     6       Ceylon     0       1       0      1
# ...    ...        ...   ...          ...   ...     ...     ...    ...
# 3055  2018      Wushu     5      Vietnam     0       2       3      5
# 3056  2018      Wushu     6  South Korea     0       1       2      3
# 3057  2018      Wushu     7    Hong Kong     0       1       1      2
# 3058  2018      Wushu     8        Japan     0       1       0      1
# 3059  2018      Wushu     8   Uzbekistan     0       1       0      1
#
#      Host_Country
# 0           India
# 1           India
# 2           India
# 3           India
# 4           India
# ...

# %%
#Overall analysis:
host=host.groupby(['Year','Country'])['Gold','Silver','Bronze','Total'].agg(sum).reset_index()
# Out:
# C:\Users\DEEPAK~1\AppData\Local\Temp/ipykernel_5984/3140264296.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   host=host.groupby(['Year','Country'])['Gold','Silver','Bronze','Total'].agg(sum).reset_index()

# %%
host
# Out:
#     Year      Country  Gold  Silver  Bronze  Total
# 0   1951        India    15      16      20     51
# 1   1954  Philippines    14      14      17     45
# 2   1958        Japan    67      41      30    138
# 3   1962    Indonesia    12      14      29     55
# 4   1966     Thailand    12      14      11     37
# 5   1970     Thailand     9      17      13     39
# 6   1974         Iran    36      28      17     81
# 7   1978     Thailand    11      12      19     42
# 8   1982        India    13      19      25     57
# 9   1986  South Korea    93      55      76    224
# 10  1990        China   183     107      51    341
# 11  1994        Japan    63      74      79    216
# 12  1998     Thailand    25      26      40     91
# 13  2002  South Korea    96      80      84    260
# 14  2006        Qatar     9      12      11     32
# 15  2010        China   197     117      98    412
# 16  2014  South Korea    79      70      79    228
# ...

# %%
host=host.groupby(['Country'])['Gold','Silver','Bronze','Total'].mean().reset_index()
# Out:
# C:\Users\DEEPAK~1\AppData\Local\Temp/ipykernel_5984/2765831471.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   host=host.groupby(['Country'])['Gold','Silver','Bronze','Total'].mean().reset_index()

# %%
host=host.rename(columns={'Gold':'Gold/Yr','Silver':'Silver/Yr','Bronze':'Bronze/Yr','Total':'Total/Yr'})

# %%
host
# Out:
#        Country     Gold/Yr   Silver/Yr  Bronze/Yr    Total/Yr
# 0        China  190.000000  112.000000  74.500000  376.500000
# 1        India   14.000000   17.500000  22.500000   54.000000
# 2    Indonesia   21.500000   19.000000  36.000000   76.500000
# 3         Iran   36.000000   28.000000  17.000000   81.000000
# 4        Japan   65.000000   57.500000  54.500000  177.000000
# 5  Philippines   14.000000   14.000000  17.000000   45.000000
# 6        Qatar    9.000000   12.000000  11.000000   32.000000
# 7  South Korea   89.333333   68.333333  79.666667  237.333333
# 8     Thailand   14.250000   17.250000  20.750000   52.250000

# %%
#Overall analysis:
non_host=non_host.groupby(['Year','Country'])['Gold','Silver','Bronze','Total'].agg(sum).reset_index()
# Out:
# C:\Users\DEEPAK~1\AppData\Local\Temp/ipykernel_5984/1609705489.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   non_host=non_host.groupby(['Year','Country'])['Gold','Silver','Bronze','Total'].agg(sum).reset_index()

# %%
non_host
# Out:
#      Year               Country  Gold  Silver  Bronze  Total
# 0    1951                 Burma     0       0       3      3
# 1    1951                Ceylon     0       1       0      1
# 2    1951             Indonesia     0       0       5      5
# 3    1951                  Iran     8       6       2     16
# 4    1951                 Japan    24      21      15     60
# ..    ...                   ...   ...     ...     ...    ...
# 420  2018              Thailand    11      16      47     74
# 421  2018          Turkmenistan     0       1       2      3
# 422  2018  United Arab Emirates     3       6       5     14
# 423  2018            Uzbekistan    20      24      25     69
# 424  2018               Vietnam     5      15      19     39
#
# [425 rows x 6 columns]

# %%
non_host=non_host.groupby(['Country'])['Gold','Silver','Bronze','Total'].mean().reset_index()
# Out:
# C:\Users\DEEPAK~1\AppData\Local\Temp/ipykernel_5984/833876694.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   non_host=non_host.groupby(['Country'])['Gold','Silver','Bronze','Total'].mean().reset_index()

# %%
non_host
# Out:
#                  Country        Gold     Silver     Bronze       Total
# 0            Afghanistan    0.000000   0.555556   0.888889    1.444444
# 1                Bahrain    5.000000   3.428571   3.142857   11.571429
# 2             Bangladesh    0.142857   0.571429   0.857143    1.571429
# 3                 Brunei    0.000000   0.000000   1.333333    1.333333
# 4                  Burma    1.250000   1.250000   3.500000    6.000000
# 5               Cambodia    1.000000   0.000000   0.666667    1.666667
# 6                 Ceylon    0.500000   1.000000   1.833333    3.333333
# 7                  China  108.900000  76.800000  57.100000  242.800000
# 8         Chinese Taipei   10.750000  15.250000  28.375000   54.250000
# 9              Hong Kong    2.533333   5.533333   7.466667   15.533333
# 10                 India    7.875000  10.187500  17.000000   35.062500
# 11             Indonesia    3.062500   5.187500  10.812500   19.062500
# ...

# %%
non_host=non_host.rename(columns={'Gold':'Gold/Yr','Silver':'Silver/Yr','Bronze':'Bronze/Yr','Total':'Total/Yr'})

# %%
non_host=non_host.sort_values(["Gold/Yr","Silver/Yr","Bronze/Yr"],ascending=False).reset_index(drop=True)

# %%
non_host
# Out:
#                  Country     Gold/Yr  Silver/Yr  Bronze/Yr    Total/Yr
# 0                  China  108.900000  76.800000  57.100000  242.800000
# 1                  Japan   56.375000  57.750000  54.687500  168.875000
# 2            South Korea   33.928571  32.714286  42.000000  108.714286
# 3             Kazakhstan   22.142857  22.714286  34.714286   79.571429
# 4             Uzbekistan   11.857143  17.142857  20.000000   49.000000
# 5            North Korea   11.000000  14.300000  17.800000   43.000000
# 6         Chinese Taipei   10.750000  15.250000  28.375000   54.250000
# 7                   Iran   10.214286  10.928571  12.857143   34.000000
# 8                  India    7.875000  10.187500  17.000000   35.062500
# 9               Thailand    6.333333   8.750000  16.333333   31.416667
# 10               Bahrain    5.000000   3.428571   3.142857   11.571429
# 11              Malaysia    4.285714   6.928571   9.714286   20.928571
# ...

# %%
#Creating a list that will only have the 9 host nations of Asian games.
li=[]
for item in host['Country']:
    li.append(item)

# %%
#If any country in non_host doesn't belongs in the above list, then remove it out as it's of no use.
for i in range(len(non_host)):
    if non_host['Country'].loc[i] not in li:
        non_host['Country'].loc[i]='Not_host'
# Out:
# C:\Users\Deepak Raj\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
non_host=non_host[non_host['Country']!='Not_host'].reset_index(drop=True)

# %%
non_host=non_host.sort_values(['Country']).reset_index(drop=True)

# %%
host=host.sort_values(['Country']).reset_index(drop=True)

# %%
non_host
# Out:
#        Country     Gold/Yr  Silver/Yr  Bronze/Yr    Total/Yr
# 0        China  108.900000  76.800000  57.100000  242.800000
# 1        India    7.875000  10.187500  17.000000   35.062500
# 2    Indonesia    3.062500   5.187500  10.812500   19.062500
# 3         Iran   10.214286  10.928571  12.857143   34.000000
# 4        Japan   56.375000  57.750000  54.687500  168.875000
# 5  Philippines    3.117647   5.882353  12.588235   21.588235
# 6        Qatar    3.777778   2.111111   3.888889    9.777778
# 7  South Korea   33.928571  32.714286  42.000000  108.714286
# 8     Thailand    6.333333   8.750000  16.333333   31.416667

# %%
host
# Out:
#        Country     Gold/Yr   Silver/Yr  Bronze/Yr    Total/Yr
# 0        China  190.000000  112.000000  74.500000  376.500000
# 1        India   14.000000   17.500000  22.500000   54.000000
# 2    Indonesia   21.500000   19.000000  36.000000   76.500000
# 3         Iran   36.000000   28.000000  17.000000   81.000000
# 4        Japan   65.000000   57.500000  54.500000  177.000000
# 5  Philippines   14.000000   14.000000  17.000000   45.000000
# 6        Qatar    9.000000   12.000000  11.000000   32.000000
# 7  South Korea   89.333333   68.333333  79.666667  237.333333
# 8     Thailand   14.250000   17.250000  20.750000   52.250000

# %%
#Medals won on an average as hosts and as non hosts comparison graphically:
plt.figure(figsize=(15,5))
plt.title("Yearwise total medals won as host country and as non host country:")
plt.bar(host['Country'],host['Total/Yr'],width=0.1,label='host')
plt.bar(non_host['Country'],non_host['Total/Yr'],width=0.1,label='non-host')
plt.legend()
plt.show()

# %%
#Medals won on an average as hosts and as non hosts comparison graphically:
plt.figure(figsize=(15,5))
plt.title("Yearwise gold medals won as host country and as non host country:")
plt.bar(host['Country'],host['Gold/Yr'],width=0.1,label='host')
plt.bar(non_host['Country'],non_host['Gold/Yr'],width=0.1,label='non-host')
plt.legend()
plt.show()

# %%
#Medals won on an average as hosts and as non hosts comparison graphically:
plt.figure(figsize=(15,5))
plt.title("Yearwise silver medals won as host country and as non host country:")
plt.bar(host['Country'],host['Silver/Yr'],width=0.1,label='host')
plt.bar(non_host['Country'],non_host['Silver/Yr'],width=0.1,label='non-host')
plt.legend()
plt.show()

# %%
#Medals won on an average as hosts and as non hosts comparison graphically:
plt.figure(figsize=(15,5))
plt.title("Yearwise bronze medals won as host country and as non host country:")
plt.bar(host['Country'],host['Bronze/Yr'],width=0.1,label='host')
plt.bar(non_host['Country'],non_host['Bronze/Yr'],width=0.1,label='non-host')
plt.legend()
plt.show()

# %%
#Medals won on an average as hosts and as non hosts comparison graphically:
plt.figure(figsize=(15,5))
plt.title("Yearwise total medals won as host country and as non host country:")

X_axis = np.arange(len(host['Country']))
plt.bar(X_axis - 0.2,host['Total/Yr'],width=0.1,label='host-Total',color='yellow')
plt.bar(X_axis - 0.1,host['Gold/Yr'],width=0.1,label='host-Gold')
plt.bar(X_axis + 0.0,host['Silver/Yr'],width=0.1,label='host-Silver')
plt.bar(X_axis + 0.1,host['Bronze/Yr'],width=0.1,label='host-Bronze')
plt.xticks(X_axis, host['Country'])

plt.bar(X_axis - 0.2,non_host['Total/Yr'],width=0.1,label='non-host-Total')
plt.bar(X_axis - 0.1,non_host['Gold/Yr'],width=0.1,label='non-host-Gold')
plt.bar(X_axis + 0.0,non_host['Silver/Yr'],width=0.1,label='non-host-Silver')
plt.bar(X_axis + 0.1,non_host['Bronze/Yr'],width=0.1,label='non-host-Bronze')
plt.xticks(X_axis, non_host['Country'])

plt.legend()
plt.show()

# %% [markdown]
# **For Asian Games, From the above graph, we can infer that the number of total medals and gold medals are highly affected by playing as host nation. Silver and Bronze are little affected but, they are slightly more than medals as non host country. For Japan only the performance as host nation and away nation isalmost the same.**

# %% [markdown]
# **Other asian countries have never been host in Asian games from 1950 onwards. So their data is filtered out in this analysis by default.**

# %%
host.to_csv("Q4-c.csv",index=False)

# %%
non_host.to_csv("Q4-d.csv",index=False)

# %% [markdown]
# **For Olympics and Asian games plot these graphs independently. For Both, plot both graphs side by side and compare. They're almost same. Only Japan is the odd one out. It's performance in Asian games is similar as host and non host country. But, in Olympics, it becomes drastically better.**

# %% [markdown]
# **We've successfully completed Q4 and generated various insights from the data.**
